# %% [markdown]
# # Authors:
#
# - Luca Erbì
# - Gabriele Lorenzo

# %% [markdown]
# # Lab 5: Text to SQL
#
# In this lab, we'll apply what we've already learned in the previous labs to build a sqlite database using Ministral 8b. This lab is less guided than the previous ones and you'll need to refer to what you've done previously to complete each part. Moreover, this lab is more focused on prompt engineering and you have to find the best prompt and prompt strategy (system prompt? temperature value? dialog prompt style?).
#
# For this lab, we need to use sqlite3 to execute the generated queries.
# Check the doc: https://docs.python.org/3/library/sqlite3.html
#
# <font color='red'>BE CAREFUL: you need to generate sql queries then automaticly exectute them with sqlite3 connector. DO NOT generate python code. DO NOT copy paste genereted query to the connector.</font>
#
# <font color='green'>TIPS: sqlite3 create a file containing your db. Delete it if you need to reset the db.</font>
#
# Lab overview:
#
# 0. Modules installation and model loading.
# 1. Create tables using llm.
# 2. Populate tables using llm.
# 3. Explore our tables using llm.
# 4. More than one table with llm.
#
# IMPORTANT:
#
# - You must work in pairs. You must submit **ONLY ONE NOTEBOOK** for each pair.
# - Do not share your work with other pairs.
# - You should not use Copilot, ChatGPT or similar tools. At the very least, remove the prompt ...

# %% [markdown]
# ## 0. Setup

# %%
# !pip install -U transformers datasets bitsandbytes accelerate

# %%
from transformers import (
    BitsAndBytesConfig,
    AutoTokenizer,
    AutoModelForCausalLM,
    GenerationConfig,
)

from tqdm.notebook import tqdm as tqdm_notebook
import sqlite3
import torch
import re

# %%
# Put your hugging face token here: https://huggingface.co/docs/hub/en/security-tokens
# You need to fill the access form with your huggingface account on this link: https://huggingface.co/mistralai/Ministral-8B-Instruct-2410
hf_token = ""
llm_name = "mistralai/Ministral-8B-Instruct-2410"

# We want to use 4bit quantization to save memory
quantization_config = BitsAndBytesConfig(load_in_8bit=False, load_in_4bit=True)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(llm_name, padding_side="left", token=hf_token)
# Prevent some transformers specific issues.
tokenizer.use_default_system_prompt = False
tokenizer.pad_token_id = tokenizer.eos_token_id

# Load LLM.
llm = AutoModelForCausalLM.from_pretrained(
    llm_name,
    quantization_config=quantization_config,
    device_map={"": 0},  # load all the model layers on GPU 0
    torch_dtype=torch.bfloat16,  # float precision
    token=hf_token,
)
# Set LLM on eval mode.
llm.eval()
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(131072, 4096)
#     (layers): ModuleList(
#       (0-35): 36 x MistralDecoderLayer(
#         (self_attn): MistralAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): MistralMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=12288, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=12288, bias=False)
#           (down_proj): Linear4bit(in_features=12288, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): MistralRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): MistralRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=131072, bias=False)
# )

# %% [markdown]
# ## 1. Create tables using llms
#
# You need to generate and execute SQL queries to create 3 tables:
#
# - "characters": Id (primary key), Name (str), Age (int), Profession (int).
# - "characters20": same than characters.
# - "skills": Id (primary key), Name (str), Profession (str).
#
# For example, by running this code `cursor.execute("""PRAGMA table_info(characters);""").fetchall()`.
#
# You should have this results:
#
# ```
# `[(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 1, None, 0),
#  (2, 'age', 'INTEGER', 1, None, 0),
#  (3, 'profession', 'TEXT', 1, None, 0)]
# ```
#
# <font color='red'>BE CAREFUL: sqlite3 doesn't have the same possibility than SQL. You may need to specify it.</font>

# %%
generation_config = GenerationConfig(
    max_new_tokens=512,
    do_sample=False,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.pad_token_id,
)

# %%
characters = """characters(Id (primary key autoincrement), Name (str not null), Age (int not null), Profession (str not null))"""
characters20 = """characters20(Id (primary key autoincrement), Name (str not null), Age (int not null), Profession (str not null))"""
skills = """skills(Id (primary key autoincrement), Name (str not null), Profession (str not null))"""

template_create = """
This is the table:
{table}
This is the text:
Write the query to create the table in sqlite3.
```
"""

template_refine = """
This is the table:
{table}
This is the text:
Write the query to create the table in sqlite3.
This is the reference:
```sql
{reference}
```
The reference SQL may be correct or incorrect.
If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
"""

tables = [characters, characters20, skills]

# create sqlite cursor
conn = sqlite3.connect("lab5.db")
cursor = conn.cursor()

# %%
def generate_table(table):
    prompt_text = template_create.format(table=table)
    input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

    generation_output = llm.generate(
        input_ids=input_ids,
        generation_config=generation_config,
    )
    generation_text = tokenizer.decode(generation_output[0][len(input_ids[0]) :])

    matches = re.findall(
        r"CREATE TABLE .*?\)", generation_text, re.DOTALL | re.IGNORECASE
    )
    if len(matches) == 0:
        print(generation_text)
        print("No matches found")
        return
    generate_table_cmd = matches[0]

    try:
        cursor.execute(generate_table_cmd)
        conn.commit()
    except Exception as e:
        print(e)


# clear all tables
cursor.execute("DROP TABLE IF EXISTS characters")
cursor.execute("DROP TABLE IF EXISTS characters20")
cursor.execute("DROP TABLE IF EXISTS skills")
conn.commit()

for table in tqdm_notebook(tables):
    generate_table(table)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
print(cursor.execute(f"PRAGMA table_info(characters);").fetchall())
print(cursor.execute(f"PRAGMA table_info(characters20);").fetchall())
print(cursor.execute(f"PRAGMA table_info(skills);").fetchall())
# Out:
# [(0, 'Id', 'INTEGER', 0, None, 1), (1, 'Name', 'TEXT', 1, None, 0), (2, 'Age', 'INTEGER', 1, None, 0), (3, 'Profession', 'TEXT', 1, None, 0)]
# [(0, 'Id', 'INTEGER', 0, None, 1), (1, 'Name', 'TEXT', 1, None, 0), (2, 'Age', 'INTEGER', 1, None, 0), (3, 'Profession', 'TEXT', 1, None, 0)]
# [(0, 'Id', 'INTEGER', 0, None, 1), (1, 'Name', 'TEXT', 1, None, 0), (2, 'Profession', 'TEXT', 1, None, 0)]

# %% [markdown]
# ## 2. Populate tables using llm
#
# You need to generate and execute SQL queries to fill in “characters” and “characters20” :
#
# - For both, the age must be constrained between 18 and 50 (we'll assess whether the constraint is met later).
# - For “characters”, generate 10 rows using the prompt. Apply the prompt 10 times (you should end up with 100 lines).
# - For “characters20”, generate 20 rows using the prompt. Apply the prompt 5 times (you should also get 100 lines at the end).
#
# For example, executing this code `cursor.execute("SELECT * FROM characters")`.
#
# You should get this result (with 100 rows and perhaps different values ...) :
#
# ```
# [(1, 'Alice', 25, 'Artist'),
#  (2, 'Bob', 35, 'Engineer'),
#   ...
#  (99, 'Ian', 32, 'Architect'),
#  (100, 'Jane', 18, 'Dancer')]
# ```
#
# <font color='red'> BE CAREFUL: If your generation configuration doesn't include sampling, you'll always have the same rows.</font>
#
# <font color='green'> BONUS: In section 3, we'll compare the number of duplicated rows between the two methods. Do you have a better strategy for minimizing the number of duplicated rows? Give it a try! (create another table for this purpose) </font>

# %%
generation_config = GenerationConfig(
    max_new_tokens=1024,
    do_sample=True,
    temperature=0.3,
    # top_p=.8,
    # top_k=20,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.pad_token_id,
)

# %%
template_insert = """
You have this SQLite table:
{table}

Write the SQLite3 query to insert {n_lines} populated lines of different values (not ID) into the table.
The age should be between 18 and 50.

Only use sqlite3 syntax, you are not allowed to use any other language syntax.
Just write the query and NOTHING else. Do not execute it.

This is an example of insertion query in sqlite3:
```sql
INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
```
"""


def apply_insert_prompt(table, n_iter, n_lines):
    for i in tqdm_notebook(range(n_iter)):
        prompt_text = template_insert.format(table=table, n_lines=n_lines)
        input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

        generation_output = llm.generate(
            input_ids=input_ids,
            generation_config=generation_config,
        )
        generation_text = tokenizer.decode(generation_output[0][len(input_ids[0]) :])

        matches = re.findall(
            r"INSERT INTO.*?;", generation_text, re.DOTALL | re.IGNORECASE
        )
        if len(matches) == 0:
            raise Exception("No matches found")

        print(f"QUERY {i + 1}:")
        print(matches)
        print("-" * 80)

        for match in matches:
            try:
                cursor.execute(match)
                conn.commit()
            except Exception as e:
                print(e)


cursor.execute("DELETE FROM characters")
apply_insert_prompt(characters, n_iter=10, n_lines=10)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# QUERY 1:
# ["INSERT INTO characters (Name, Age, Profession) VALUES\n('John Doe', 25, 'Engineer'),\n('Jane Smith', 30, 'Doctor'),\n('Alice Johnson', 35, 'Teacher'),\n('Bob Brown', 40, 'Artist'),\n('Charlie Green', 45, 'Writer'),\n('David White', 50, 'Musician'),\n('Eve Black', 20, 'Designer'),\n('Frank Yellow', 30, 'Chef'),\n('Grace Blue', 40, 'Nurse'),\n('Helen Red', 50, 'Artist');"]
# --------------------------------------------------------------------------------
# QUERY 2:
# ["INSERT INTO characters (Name, Age, Profession) VALUES\n('John Doe', 25, 'Engineer'),\n('Jane Smith', 30, 'Doctor'),\n('Alice Johnson', 40, 'Teacher'),\n('Bob Brown', 28, 'Artist'),\n('Charlie Green', 35, 'Writer'),\n('David White', 45, 'Lawyer'),\n('Eva Black', 32, 'Nurse'),\n('Frank Blue', 50, 'Engineer'),\n('Grace Red', 22, 'Teacher'),\n('Helen Yellow', 48, 'Doctor');"]
# --------------------------------------------------------------------------------
# QUERY 3:
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('Alice', 25, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Bob', 30, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie', 35, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('David', 40, 'Artist');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Eve', 45, 'Writer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Frank', 50, 'Musician');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Grace', 20, 'Nurse');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Helen', 28, 'Lawyer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Ivan', 32, 'Chef');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Jane', 42, 'Architect');"]
# --------------------------------------------------------------------------------
# QUERY 4:
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('Alice', 25, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Bob', 30, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie', 35, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('David', 40, 'Artist');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Eve', 45, 'Writer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Frank', 50, 'Musician');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Grace', 20, 'Designer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Helen', 28, 'Chef');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Ian', 32, 'Architect');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Judy', 42, 'Nurse');"]
# --------------------------------------------------------------------------------
# QUERY 5:
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('Alice', 25, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Bob', 30, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie', 35, 'Artist');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Diana', 40, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Eve', 45, 'Writer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Frank', 50, 'Lawyer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Grace', 20, 'Chef');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Helen', 28, 'Nurse');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Ivan', 32, 'Architect');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Judy', 42, 'Musician');"]
# --------------------------------------------------------------------------------
# QUERY 6:
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('John Doe', 25, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Jane Doe', 30, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Alice Smith', 40, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Bob Johnson', 35, 'Artist');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie Brown', 28, 'Writer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Diana Prince', 45, 'Nurse');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Eddie Murphy', 50, 'Actor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Fiona Apple', 22, 'Musician');", "INSERT INTO characters (Name, Age, Profession) VALUES ('George Clooney', 48, 'Actor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Helen Mirren', 35, 'Actor');"]
# --------------------------------------------------------------------------------
# QUERY 7:
# ["INSERT INTO characters (Name, Age, Profession) VALUES\n('John Doe', 25, 'Engineer'),\n('Jane Doe', 30, 'Doctor'),\n('Alice Smith', 40, 'Teacher'),\n('Bob Johnson', 50, 'Lawyer'),\n('Charlie Brown', 20, 'Artist'),\n('David Wilson', 35, 'Writer'),\n('Eve Davis', 45, 'Nurse'),\n('Frank Miller', 15, 'Student'),\n('Grace Johnson', 28, 'Chef'),\n('Helen Davis', 38, 'Musician');"]
# --------------------------------------------------------------------------------
# QUERY 8:
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('Alice', 25, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Bob', 30, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie', 35, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('David', 40, 'Artist');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Eve', 45, 'Writer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Frank', 50, 'Musician');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Grace', 55, 'Nurse');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Helen', 60, 'Lawyer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Ian', 65, 'Architect');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Judy', 70, 'Chef');"]
# --------------------------------------------------------------------------------
# QUERY 9:
# ["INSERT INTO characters (Name, Age, Profession) VALUES\n('Alice', 25, 'Doctor'),\n('Bob', 30, 'Engineer'),\n('Charlie', 35, 'Teacher'),\n('David', 40, 'Artist'),\n('Eve', 45, 'Writer'),\n('Frank', 50, 'Musician'),\n('Grace', 20, 'Nurse'),\n('Heidi', 28, 'Chef'),\n('Ivan', 32, 'Architect'),\n('Judy', 38, 'Lawyer');"]
# --------------------------------------------------------------------------------
# QUERY 10:
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('Name1', 18, 'Profession1');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Name2', 20, 'Profession2');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Name3', 25, 'Profession3');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Name4', 30, 'Profession4');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Name5', 35, 'Profession5');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Name6', 40, 'Profession6');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Name7', 45, 'Profession7');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Name8', 50, 'Profession8');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Name9', 48, 'Profession9');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Name10', 38, 'Profession10');"]
# --------------------------------------------------------------------------------

# %%
cursor.execute("DELETE FROM characters20")
apply_insert_prompt(characters20, n_iter=5, n_lines=20)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# QUERY 1:
# ["INSERT INTO characters20 (Name, Age, Profession) VALUES\n('Alice', 25, 'Engineer'),\n('Bob', 30, 'Doctor'),\n('Charlie', 35, 'Teacher'),\n('David', 40, 'Artist'),\n('Eve', 45, 'Writer'),\n('Frank', 50, 'Musician'),\n('Grace', 18, 'Student'),\n('Helen', 20, 'Nurse'),\n('Ivan', 25, 'Chef'),\n('Judy', 30, 'Teacher'),\n('Kate', 35, 'Artist'),\n('Larry', 40, 'Writer'),\n('Megan', 45, 'Musician'),\n('Nancy', 50, 'Student'),\n('Oscar', 18, 'Nurse'),\n('Peter', 20, 'Chef'),\n('Quincy', 25, 'Teacher'),\n('Rachel', 30, 'Artist'),\n('Sam', 35, 'Writer'),\n('Tina', 40, 'Musician'),\n('Ursula', 45, 'Student'),\n('Victor', 50, 'Nurse');"]
# --------------------------------------------------------------------------------
# QUERY 2:
# ["INSERT INTO characters20 (Name, Age, Profession) VALUES\n('Alice', 25, 'Teacher'),\n('Bob', 30, 'Doctor'),\n('Charlie', 35, 'Engineer'),\n('David', 40, 'Artist'),\n('Eve', 45, 'Musician'),\n('Frank', 50, 'Writer'),\n('Grace', 55, 'Actor'),\n('Helen', 60, 'Designer'),\n('Ivy', 65, 'Photographer'),\n('Jack', 70, 'Director'),\n('Karen', 75, 'Producer'),\n('Larry', 80, 'Editor'),\n('Megan', 85, 'Writer'),\n('Nancy', 90, 'Designer'),\n('Owen', 95, 'Actor'),\n('Peter', 100, 'Photographer'),\n('Quinn', 105, 'Director'),\n('Rachel', 110, 'Producer'),\n('Steve', 115, 'Editor');"]
# --------------------------------------------------------------------------------
# QUERY 3:
# ["INSERT INTO characters20 (Name, Age, Profession)\nVALUES ('John Doe', 25, 'Engineer'), ('Jane Doe', 30, 'Doctor'), ('Alice Smith', 45, 'Teacher'), ('Bob Johnson', 18, 'Student'), ('Charlie Brown', 22, 'Artist'), ('Diana Prince', 35, 'Nurse'), ('Eva Green', 40, 'Writer'), ('Frank White', 28, 'Chef'), ('Grace Lee', 38, 'Designer'), ('Helen Clark', 29, 'Architect'), ('Ivy Johnson', 42, 'Musician'), ('Jack Smith', 33, 'Actor'), ('Karen Brown', 27, 'Photographer'), ('Linda Green', 50, 'Artist'), ('Megan White', 31, 'Teacher'), ('Nancy Clark', 44, 'Writer'), ('Oscar Johnson', 26, 'Designer'), ('Paul Brown', 39, 'Musician'), ('Quincy Green', 48, 'Chef'), ('Rachel Clark', 21, 'Nurse'), ('Sam Smith', 37, 'Writer'), ('Tina White', 32, 'Designer'), ('Ursula Johnson', 23, 'Actor'), ('Victor Brown', 46, 'Photographer'), ('Wendy Green', 34, 'Musician'), ('Xavier Clark', 41, 'Writer'), ('Yvonne Johnson', 20, 'Designer'), ('Zach Smith', 36, 'Nurse');"]
# --------------------------------------------------------------------------------
# QUERY 4:
# ["INSERT INTO characters20 (Name, Age, Profession) VALUES ('Alice', 25, 'Doctor'), ('Bob', 30, 'Engineer'), ('Charlie', 35, 'Artist'), ('David', 40, 'Teacher'), ('Eve', 45, 'Nurse'), ('Frank', 50, 'Lawyer'), ('Grace', 20, 'Chef'), ('Helen', 25, 'Artist'), ('Ivy', 30, 'Teacher'), ('Jack', 35, 'Engineer'), ('Karen', 40, 'Doctor'), ('Linda', 45, 'Nurse'), ('Megan', 50, 'Lawyer'), ('Nancy', 20, 'Chef'), ('Owen', 25, 'Artist'), ('Paul', 30, 'Teacher'), ('Quincy', 35, 'Engineer'), ('Rachel', 40, 'Doctor'), ('Steve', 45, 'Nurse'), ('Tina', 50, 'Lawyer');"]
# --------------------------------------------------------------------------------
# QUERY 5:
# ["INSERT INTO characters20 (Name, Age, Profession) VALUES ('John Doe', 25, 'Actor');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Jane Smith', 30, 'Doctor');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Emily Johnson', 45, 'Engineer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Michael Brown', 35, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Olivia Davis', 28, 'Artist');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('James Wilson', 40, 'Lawyer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Sophia Martinez', 32, 'Writer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Daniel Taylor', 50, 'Architect');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ava Anderson', 22, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Benjamin Clark', 38, 'Chef');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Isabella Lewis', 42, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Oliver Martinez', 29, 'Artist');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Sophia Davis', 35, 'Engineer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Daniel Clark', 48, 'Doctor');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ava Johnson', 27, 'Lawyer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Benjamin Wilson', 33, 'Writer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Isabella Taylor', 45, 'Architect');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Oliver Martinez', 30, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Sophia Davis', 40, 'Chef');"]
# --------------------------------------------------------------------------------

# %%
print(
    f"Number of rows in characters: {cursor.execute('SELECT COUNT(*) FROM characters;').fetchone()[0]}"
)
print(
    f"Number of rows in characters20: {cursor.execute('SELECT COUNT(*) FROM characters20;').fetchone()[0]}"
)
# Out:
# Number of rows in characters: 100
# Number of rows in characters20: 108

# %% [markdown]
# ## 3. Explore our tables using llm.
#
# First, you need to generate and execute SQL queries that indicate the number of duplicate rows (without ids) in each character table. To make things easier, we only ask for the number of each duplicated rows.
#
# Here is an examples of expected results:
#
# ```
# [(2,), (7,), (5,), (2,), (2,), (3,), (2,), (2,), (2,), (2,), (2,), (2,), (2,)]
# ```
#
# <font color='green'> BONUS: Generate a query that returns the total count of duplicated rows. You may need to do this in several steps.</font>
#
# Secondly, you need to generate and execute SQL queries that remove duplicate rows. To make things easier, it's not necessary to keep original duplicated lines. For example, if you have a list like this : [a, b, a, c]. We ask you to remove all the a: [b, c].
#
# <font color='green'> BONUS: Generate a query that delete duplicated but keep the original row. [a, b, a, c] -> [a, b, c] </font>
#
# Finaly, you need to generate and execute SQL queries that check if the age constraint is respected.
#
# <font color='red'> BE CAREFUL: Do each step for every characters tables you have.</font>

# %%
template_query = """
You have this SQLite table:
{table}

Write the SQLite3 query to satisfy this request, you may need to do this in several steps: {action}

The query should be written in sqlite3 syntax, you are not allowed to use any other language syntax.
The query should be written between ```sql <QUERY>```.
"""

template_refine_query = """
You have this SQLite table:
{table}

You have this SQLite code to do satisfy this request: {action}
```sql
{reference}
```

The SQLite code may be correct or incorrect.
If the SQLite code is correct and written in sqlite3 format, just say 'IT IS CORRECT'.
If the SQLite code is incorrect, modify the SQLite code and write the SQLite3 query to do satisfy the request. 
The query should be written between ```sql <QUERY>```.
"""

actions = [
    # Duplicate rows separately
    "Compute the total number of duplicate rows (ALL columns WITHOUT ids), that appear more than once, separately for each row. The result should be like this: [(2,), (7,), (5,), ...]",
    # ----------------------------------
    # Duplicate rows total
    "Count the total number of duplicate rows, ignoring the Id column. A row is considered a duplicate if it has the same columns (not considering the Id) as another row. The query should first count how many times each combination appears and then sum up only the duplicates.",
    # ----------------------------------
    # Delete duplicate rows
    "First compute the count of duplicate rows (ALL columns WITHOUT ids), that appear more than once, separately for each row. Then delete these rows.",
    # ----------------------------------
    # Delete duplicate rows but keep one copy
    "Delete the duplicated rows but keep the original row. A duplicated row is a row that has the same values in all columns (except the ID) as another row. This is an example of the final result you should obtain [row_a, row_b, row_a, row_c] -> [row_a, row_b, row_c]. Do Everything in one query.",
    # ----------------------------------
    # Age constraint
    "Show the rows where the age is lower than 18 or greater than 50.",
]


def apply_query_prompt(table, action, execute=True):
    prompt_text = template_query.format(table=table, action=action)
    input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

    generation_output = llm.generate(
        input_ids=input_ids,
        generation_config=generation_config,
    )
    generation_text = tokenizer.decode(generation_output[0][len(input_ids[0]) :])

    matches = re.search(r"```sql(.*?)```", generation_text, re.DOTALL)
    if matches is None:
        raise Exception("No matches found")
    match = matches.group(0).split("\n")[1:-1]
    match = "\n".join(match)

    print("QUERY:")
    print(match)

    try:
        if execute:
            result = cursor.execute(match).fetchall()
            print(f"RESULT OF THE QUERY:\n{result}\n")
            return result
    except Exception as e:
        print(e)


for action in actions:
    print(f"Action: {action}\n")

    for t_name, table in {
        "characters": characters,
        "characters20": characters20,
    }.items():
        print(f"Table: {t_name}")

        if "delete" in action.lower():  # we don't execute "delete" queries
            apply_query_prompt(table, action, execute=False)
        else:
            apply_query_prompt(table, action)

        print("-" * 80)
# Out:
# Action: Compute the total number of duplicate rows (ALL columns WITHOUT ids), that appear more than once, separately for each row. The result should be like this: [(2,), (7,), (5,), ...]
#
# Table: characters
# QUERY:
# SELECT COUNT(*) FROM characters GROUP BY Name, Age, Profession HAVING COUNT(*) > 1
# RESULT OF THE QUERY:
# [(2,), (3,), (2,), (3,), (2,), (4,), (4,), (5,), (4,), (2,), (2,), (2,), (2,), (4,)]
#
# --------------------------------------------------------------------------------
# Table: characters20
# QUERY:
# SELECT COUNT(*) FROM characters20 GROUP BY Name, Age, Profession HAVING COUNT(*) > 1
# RESULT OF THE QUERY:
# [(2,), (2,)]
#
# --------------------------------------------------------------------------------
# Action: Count the total number of duplicate rows, ignoring the Id column. A row is considered a duplicate if it has the same columns (not considering the Id) as another row. The query should first count how many times each combination appears and then sum up only the duplicates.
#
# Table: characters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 84
#      82     apply_query_prompt(table, action, execute=False)
#      83 else:
# ---> 84     apply_query_prompt(table, action)
#      86 print("-" * 80)
#
# Cell In[34], line 48, in apply_query_prompt(table, action, execute)
#      45 prompt_text = template_query.format(table=table, action=action)
#      46 input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")
# ---> 48 generation_output = llm.generate(
#      49     input_ids=input_ids,
#      50     generation_config=generation_config,
#      51 )
#      52 generation_text = tokenizer.decode(generation_output[0][len(input_ids[0]) :])
#      54 matches = re.search(r"```sql(.*?)```", generation_text, re.DOTALL)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/transformers/generation/utils.py:2255, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2247     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2248         input_ids=input_ids,
#    2249         expand_size=generation_config.num_return_sequences,
#    2250         is_encoder_decoder=self.config.is_encoder_decoder,
#    2251         **model_kwargs,
#    2252     )
#    2254     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2255     result = self._sample(
#    2256         input_ids,
#    2257         logits_processor=prepared_logits_processor,
#    2258         stopping_criteria=prepared_stopping_criteria,
#    2259         generation_config=generation_config,
#    2260         synced_gpus=synced_gpus,
#    2261         streamer=streamer,
#    2262         **model_kwargs,
#    2263     )
#    2265 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2266     # 11. prepare beam search scorer
#    2267     beam_scorer = BeamSearchScorer(
#    2268         batch_size=batch_size,
#    2269         num_beams=generation_config.num_beams,
#    (...)
#    2274         max_length=generation_config.max_length,
#    2275     )
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/transformers/generation/utils.py:3254, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3251 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3253 if is_prefill:
# -> 3254     outputs = self(**model_inputs, return_dict=True)
#    3255     is_prefill = False
#    3256 else:
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/transformers/models/mistral/modeling_mistral.py:832, in MistralForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **kwargs)
#     829 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     831 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 832 outputs = self.model(
#     833     input_ids=input_ids,
#     834     attention_mask=attention_mask,
#     835     position_ids=position_ids,
#     836     past_key_values=past_key_values,
#     837     inputs_embeds=inputs_embeds,
#     838     use_cache=use_cache,
#     839     output_attentions=output_attentions,
#     840     output_hidden_states=output_hidden_states,
#     841     return_dict=return_dict,
#     842     cache_position=cache_position,
#     843     **kwargs,
#     844 )
#     846 hidden_states = outputs[0]
#     847 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/transformers/models/mistral/modeling_mistral.py:561, in MistralModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     549     layer_outputs = self._gradient_checkpointing_func(
#     550         decoder_layer.__call__,
#     551         hidden_states,
#    (...)
#     558         position_embeddings,
#     559     )
#     560 else:
# --> 561     layer_outputs = decoder_layer(
#     562         hidden_states,
#     563         attention_mask=causal_mask,
#     564         position_ids=position_ids,
#     565         past_key_value=past_key_values,
#     566         output_attentions=output_attentions,
#     567         use_cache=use_cache,
#     568         cache_position=cache_position,
#     569         position_embeddings=position_embeddings,
#     570         **flash_attn_kwargs,
#     571     )
#     573 hidden_states = layer_outputs[0]
#     575 if output_attentions:
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/transformers/models/mistral/modeling_mistral.py:262, in MistralDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     260 residual = hidden_states
#     261 hidden_states = self.post_attention_layernorm(hidden_states)
# --> 262 hidden_states = self.mlp(hidden_states)
#     263 hidden_states = residual + hidden_states
#     265 outputs = (hidden_states,)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/transformers/models/mistral/modeling_mistral.py:56, in MistralMLP.forward(self, x)
#      55 def forward(self, x):
# ---> 56     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#      57     return down_proj
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/bitsandbytes/nn/modules.py:484, in Linear4bit.forward(self, x)
#     480     x = x.to(self.compute_dtype)
#     482 bias = None if self.bias is None else self.bias.to(self.compute_dtype)
# --> 484 return bnb.matmul_4bit(x, self.weight.t(), bias=bias, quant_state=self.weight.quant_state).to(inp_dtype)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/bitsandbytes/autograd/_functions.py:533, in matmul_4bit(A, B, quant_state, out, bias)
#     531         return out
#     532 else:
# --> 533     return MatMul4Bit.apply(A, B, out, bias, quant_state)
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/torch/autograd/function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File ~/IA329-Language-Models-and-Structured-Data/venv/lib/python3.10/site-packages/bitsandbytes/autograd/_functions.py:462, in MatMul4Bit.forward(ctx, A, B, out, bias, quant_state)
#     458         return torch.empty(A.shape[:-1] + B_shape[:1], dtype=A.dtype, device=A.device)
#     460 # 1. Dequantize
#     461 # 2. MatmulnN
# --> 462 output = torch.nn.functional.linear(A, F.dequantize_4bit(B, quant_state).to(A.dtype).t(), bias)
#     464 # 3. Save state
#     465 ctx.state = quant_state
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. More than one table with llm.
#
# First, choose your best characters table (with the largest number of rows).
#
# Second, generate and execute an SQL query that returns the set of unique professions in the table.
#
# Third, generate and execute an SQL query that populates the skill tables from this set of unique professions.
#
# Fourth, generate and execute an SQL query that verifies that the professions in the skill table exist in your characters table.
#
# Finally, generate and execute an SQL query that returns the name of the skills associated with a character name (by profession).

# %%
# we select the table with the largest number of rows
table_name = (
    "characters"
    if cursor.execute("SELECT COUNT(*) FROM characters;").fetchone()[0]
    > cursor.execute("SELECT COUNT(*) FROM characters20;").fetchone()[0]
    else "characters20"
)

# %%
table_name
# Out:
# 'characters20'

# %%
actions = [
    "Return the set of unique professions in the table.",
    "Write an SQL query to find all distinct professions in the skills table that do not exist in the characters table. The skills table has a profession column, and the characters table also has a profession column. The query should return only the missing professions from skills.",
    "Return the name of the skills associated with the character name 'Alice' (group by profession). Write a single query to do this.",
]

template_insert_skill = """
You have these SQLite table(s):
{table}

Write the SQLite3 INSERT statement to populate the skills table.
The following professions are available: {professions}.
Each profession should have at least two relevant skills.
The skills should be realistic and aligned with the profession.
Do not include duplicate skills across different professions.

Only use sqlite3 syntax, you are not allowed to use any other language syntax.
Just write the query and NOTHING else. Do not execute it.

This is an example of insertion query in sqlite3:
```sql
INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
```
"""


def populate_skills(professions):
    prompt_text = template_insert_skill.format(table=skills, professions=professions)
    input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

    generation_output = llm.generate(
        input_ids=input_ids,
        generation_config=generation_config,
    )

    generation_text = tokenizer.decode(generation_output[0][len(input_ids[0]) :])

    matches = re.findall(r"INSERT INTO.*?;", generation_text, re.DOTALL | re.IGNORECASE)
    for match in matches:
        try:
            cursor.execute(match)
            conn.commit()
        except Exception as e:
            print(e)


def queries_skill(characters_table):
    # we extract the set of unique professions
    unique_professions = apply_query_prompt(characters_table, actions[0])

    # we populate the skills table
    populate_skills(unique_professions)
    print(f"\nSkills table populated with professions:")
    print(cursor.execute(f"SELECT Name FROM skills;").fetchall())
    print()

    # we verify that the professions in the skill table exist in the characters table.
    apply_query_prompt(characters20 + "\n" + skills, actions[1])

    # we verify that the skills associated with the character name 'John' are correct.
    apply_query_prompt(characters20 + "\n" + skills, actions[2])


cursor.execute("DELETE FROM skills")
characters_table = characters if table_name == "characters" else characters20
queries_skill(characters_table)
# Out:
# QUERY:
# SELECT DISTINCT Profession FROM characters20;
# RESULT OF THE QUERY:
# [('Engineer',), ('Doctor',), ('Teacher',), ('Artist',), ('Writer',), ('Musician',), ('Student',), ('Nurse',), ('Chef',), ('Actor',), ('Designer',), ('Photographer',), ('Director',), ('Producer',), ('Editor',), ('Architect',), ('Lawyer',)]
#
# near ";": syntax error
#
# Skills table populated with professions:
# [('Programming',), ('Coding',), ('Diagnosis',), ('Treatment',), ('Teaching',), ('Education',), ('Painting',), ('Drawing',), ('Writing',), ('Literature',), ('Music',), ('Composition',), ('Learning',), ('Research',), ('Nursing',), ('Patient Care',), ('Cooking',), ('Baking',), ('Acting',), ('Performing',), ('Design',), ('Graphic Design',), ('Photography',), ('Camera Work',), ('Directing',), ('Script Writing',), ('Producing',), ('Project Management',), ('Editing',), ('Video Editing',), ('Architecture',), ('Building Design',), ('Law',), ('Legal Research',)]
#
# QUERY:
# SELECT DISTINCT s.Profession
# FROM skills s
# WHERE s.Profession NOT IN (SELECT DISTINCT c.Profession
#                            FROM characters20 c);
# RESULT OF THE QUERY:
# []
#
# QUERY:
# SELECT Name
# FROM skills
# WHERE Profession IN (
#     SELECT Profession
#     FROM characters20
#     WHERE Name = 'Alice'
# );
# RESULT OF THE QUERY:
# [('Programming',), ('Coding',), ('Diagnosis',), ('Treatment',), ('Teaching',), ('Education',)]
