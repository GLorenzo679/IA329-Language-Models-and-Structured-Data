# %% [markdown]
# # Authors:
#
# - Luca Erbì
# - Gabriele Lorenzo

# %% [markdown]
# # Lab 5: Text to SQL
#
# In this lab, we'll apply what we've already learned in the previous labs to build a sqlite database using Ministral 8b. This lab is less guided than the previous ones and you'll need to refer to what you've done previously to complete each part. Moreover, this lab is more focused on prompt engineering and you have to find the best prompt and prompt strategy (system prompt? temperature value? dialog prompt style?).
#
# For this lab, we need to use sqlite3 to execute the generated queries.
# Check the doc: https://docs.python.org/3/library/sqlite3.html
#
# <font color='red'>BE CAREFUL: you need to generate sql queries then automaticly exectute them with sqlite3 connector. DO NOT generate python code. DO NOT copy paste genereted query to the connector.</font>
#
# <font color='green'>TIPS: sqlite3 create a file containing your db. Delete it if you need to reset the db.</font>
#
# Lab overview:
#
# 0. Modules installation and model loading.
# 1. Create tables using llm.
# 2. Populate tables using llm.
# 3. Explore our tables using llm.
# 4. More than one table with llm.
#
# IMPORTANT:
#
# - You must work in pairs. You must submit **ONLY ONE NOTEBOOK** for each pair.
# - Do not share your work with other pairs.
# - You should not use Copilot, ChatGPT or similar tools. At the very least, remove the prompt ...

# %% [markdown]
# ## 0. Setup

# %%
# !pip install -U transformers datasets bitsandbytes accelerate

# %%
from transformers import (
    BitsAndBytesConfig,
    AutoTokenizer,
    AutoModelForCausalLM,
    GenerationConfig,
)

from tqdm import tqdm
from tqdm.notebook import tqdm as tqdm_notebook
import pandas as pd
import sqlite3
import torch
import re

# %%
# Put your hugging face token here: https://huggingface.co/docs/hub/en/security-tokens
# You need to fill the access form with your huggingface account on this link: https://huggingface.co/mistralai/Ministral-8B-Instruct-2410
hf_token = ""
llm_name = "mistralai/Ministral-8B-Instruct-2410"

# We want to use 4bit quantization to save memory
quantization_config = BitsAndBytesConfig(load_in_8bit=False, load_in_4bit=True)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(llm_name, padding_side="left", token=hf_token)
# Prevent some transformers specific issues.
tokenizer.use_default_system_prompt = False
tokenizer.pad_token_id = tokenizer.eos_token_id

# Load LLM.
llm = AutoModelForCausalLM.from_pretrained(
    llm_name,
    quantization_config=quantization_config,
    device_map={"": 0},  # load all the model layers on GPU 0
    torch_dtype=torch.bfloat16,  # float precision
    token=hf_token,
)
# Set LLM on eval mode.
llm.eval()
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message.
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(131072, 4096)
#     (layers): ModuleList(
#       (0-35): 36 x MistralDecoderLayer(
#         (self_attn): MistralAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): MistralMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=12288, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=12288, bias=False)
#           (down_proj): Linear4bit(in_features=12288, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): MistralRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): MistralRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=131072, bias=False)
# )

# %% [markdown]
# ## 1. Create tables using llms
#
# You need to generate and execute SQL queries to create 3 tables:
#
# - "characters": Id (primary key), Name (str), Age (int), Profession (int).
# - "characters20": same than characters.
# - "skills": Id (primary key), Name (str), Profession (str).
#
# For example, by running this code `cursor.execute("""PRAGMA table_info(characters);""").fetchall()`.
#
# You should have this results:
#
# ```
# `[(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 1, None, 0),
#  (2, 'age', 'INTEGER', 1, None, 0),
#  (3, 'profession', 'TEXT', 1, None, 0)]
# ```
#
# <font color='red'>BE CAREFUL: sqlite3 doesn't have the same possibility than SQL. You may need to specify it.</font>

# %%
generation_config = GenerationConfig(
    max_new_tokens=512,
    do_sample=False,
    # temperature=.7,
    # top_p=.8,
    # top_k=20,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.pad_token_id,
)

# %%
characters = """characters(Id (primary key autoincrement), Name (str not null), Age (int not null), Profession (str not null))"""
characters20 = """characters20(Id (primary key autoincrement), Name (str not null), Age (int not null), Profession (str not null))"""
skills = """skills(Id (primary key autoincrement), Name (str not null), Profession (str not null))"""

template_create = """
This is the table:
{table}
This is the text:
Write the query to create the table in sqlite3.
```
"""

template_refine = """
This is the table:
{table}
This is the text:
Write the query to create the table in sqlite3.
This is the reference:
```sql
{reference}
```
The reference SQL may be correct or incorrect.
If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
"""

tables = [characters, characters20, skills]
# create sqlite cursor
conn = sqlite3.connect("lab5.db")
cursor = conn.cursor()

# %%
def generate_table(table):
    prompt_text = template_create.format(table=table)
    input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

    generation_output = llm.generate(
        input_ids=input_ids,
        generation_config=generation_config,
    )
    generation_text = tokenizer.decode(generation_output[0][len(input_ids[0]) :])

    matches = re.findall(
        r"CREATE TABLE .*?\)", generation_text, re.DOTALL | re.IGNORECASE
    )
    if len(matches) == 0:
        print(generation_text)
        print("No matches found")
        return
    generate_table_cmd = matches[0]

    # # last match
    # prompt_text = template_refine.format(table=table, reference=matches[0])
    # input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

    # generation_output = llm.generate(
    #     input_ids=input_ids,
    #     generation_config=generation_config,
    # )
    # generation_text = tokenizer.decode(generation_output[0])
    # print(len(generation_text) - len(prompt_text))
    # print("-" * 80)

    # # extract from the CREATE TABLE to ;
    # matches = re.findall(
    #     r"CREATE TABLE .*?\)", generation_text, re.DOTALL | re.IGNORECASE
    # )
    # print(matches[-1])

    # # add try and catch
    try:
        cursor.execute(generate_table_cmd)
        conn.commit()
    except Exception as e:
        print(e)


# clear all tables
cursor.execute("DROP TABLE IF EXISTS characters")
cursor.execute("DROP TABLE IF EXISTS characters20")
cursor.execute("DROP TABLE IF EXISTS skills")
conn.commit()

for table in tqdm_notebook(tables):
    generate_table(table)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.

# %%
print(cursor.execute(f"PRAGMA table_info(characters);").fetchall())
print(cursor.execute(f"PRAGMA table_info(characters20);").fetchall())
print(cursor.execute(f"PRAGMA table_info(skills);").fetchall())
# Out:
# [(0, 'Id', 'INTEGER', 0, None, 1), (1, 'Name', 'TEXT', 1, None, 0), (2, 'Age', 'INTEGER', 1, None, 0), (3, 'Profession', 'TEXT', 1, None, 0)]
# [(0, 'Id', 'INTEGER', 0, None, 1), (1, 'Name', 'TEXT', 1, None, 0), (2, 'Age', 'INTEGER', 1, None, 0), (3, 'Profession', 'TEXT', 1, None, 0)]
# [(0, 'Id', 'INTEGER', 0, None, 1), (1, 'Name', 'TEXT', 1, None, 0), (2, 'Profession', 'TEXT', 1, None, 0)]

# %% [markdown]
# ## 2. Populate tables using llm
#
# You need to generate and execute SQL queries to fill in “characters” and “characters20” :
#
# - For both, the age must be constrained between 18 and 50 (we'll assess whether the constraint is met later).
# - For “characters”, generate 10 rows using the prompt. Apply the prompt 10 times (you should end up with 100 lines).
# - For “characters20”, generate 20 rows using the prompt. Apply the prompt 5 times (you should also get 100 lines at the end).
#
# For example, executing this code `cursor.execute("SELECT * FROM characters")`.
#
# You should get this result (with 100 rows and perhaps different values ...) :
#
# ```
# [(1, 'Alice', 25, 'Artist'),
#  (2, 'Bob', 35, 'Engineer'),
#   ...
#  (99, 'Ian', 32, 'Architect'),
#  (100, 'Jane', 18, 'Dancer')]
# ```
#
# <font color='red'> BE CAREFUL: If your generation configuration doesn't include sampling, you'll always have the same rows.</font>
#
# <font color='green'> BONUS: In section 3, we'll compare the number of duplicated rows between the two methods. Do you have a better strategy for minimizing the number of duplicated rows? Give it a try! (create another table for this purpose) </font>

# %%
generation_config = GenerationConfig(
    max_new_tokens=1024,
    do_sample=True,
    temperature=0.3,
    # top_p=.8,
    # top_k=20,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.pad_token_id,
)

# %%
template_insert = """
You have this SQLite table:
{table}

Write the SQLite3 query to insert {n_lines} populated lines of different values (not ID) into the table.
The age should be between 18 and 50.

Only use sqlite3 syntax, you are not allowed to use any other language syntax.
Just write the query and NOTHING else. Do not execute it.

This is an example of insertion query in sqlite3:
```sql
INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
```
"""

template_insert_refine = """
You have this SQLite table:
{table}

You have this SQLite code to insert {n_lines} lines into the table:
```sql
{reference}
```

The SQLite code may be correct or incorrect.
If the SQLite code is correct and written in sqlite3 format, just say 'IT IS CORRECT' and say again the correct SQLite code.
If the SQLite code is incorrect, modify the SQLite code and write the SQLite3 query to insert {n_lines} populated lines of different values (not ID) into the table. Just write the query, do not execute it.
"""


def apply_insert_prompt(table, n_iter, n_lines):
    for _ in tqdm_notebook(range(n_iter)):
        prompt_text = template_insert.format(table=table, n_lines=n_lines)
        input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

        generation_output = llm.generate(
            input_ids=input_ids,
            generation_config=generation_config,
        )
        generation_text = tokenizer.decode(generation_output[0][len(input_ids[0]) :])
        print("FIRST GENERATION")
        print(generation_text)
        print("-" * 80)

        # matches = re.findall(
        #     r"```sql .*?```", generation_text, re.DOTALL | re.IGNORECASE
        # )
        matches = re.findall(
            r"INSERT INTO.*?;", generation_text, re.DOTALL | re.IGNORECASE
        )
        if len(matches) == 0:
            raise Exception("No matches found")
        print("FIRST MATCH")
        print(matches)
        print("-" * 80)

        for match in matches:
            try:
                cursor.execute(match)
                conn.commit()
            except Exception as e:
                print(e)

        # prompt_text = template_insert_refine.format(
        #     table=table, reference=matches[0], n_lines=n_lines
        # )
        # input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

        # generation_output = llm.generate(
        #     input_ids=input_ids,
        #     generation_config=generation_config,
        # )
        # generation_text = tokenizer.decode(generation_output[0][len(input_ids[0]) :])
        # print("SECOND GENERATION")
        # print(generation_text)
        # print("-" * 80)

        # matches = re.findall(
        #     r"INSERT INTO.*?;", generation_text, re.DOTALL | re.IGNORECASE
        # )
        # print("SECOND MATCH")
        # print(matches)
        # print("-" * 80)

        # if len(matches) == 0:
        #     raise Exception("No matches found")

        # for match in matches:
        #     try:
        #         cursor.execute(match)
        #         conn.commit()
        #     except Exception as e:
        #         print(e)


cursor.execute("DELETE FROM characters")
apply_insert_prompt(characters, n_iter=10, n_lines=10)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# FIRST GENERATION
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('John Doe', 30, 'Actor'), ('Jane Doe', 25, 'Actress'), ('Bob Smith', 40, 'Engineer'), ('Alice Johnson', 35, 'Doctor'), ('Charlie Brown', 28, 'Teacher'), ('David Wilson', 45, 'Artist'), ('Eva Davis', 22, 'Writer'), ('Frank Miller', 38, 'Architect'), ('Grace Lee', 42, 'Nurse'), ('Helen Clark', 33, 'Lawyer');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('John Doe', 30, 'Actor'), ('Jane Doe', 25, 'Actress'), ('Bob Smith', 40, 'Engineer'), ('Alice Johnson', 35, 'Doctor'), ('Charlie Brown', 28, 'Teacher'), ('David Wilson', 45, 'Artist'), ('Eva Davis', 22, 'Writer'), ('Frank Miller', 38, 'Architect'), ('Grace Lee', 42, 'Nurse'), ('Helen Clark', 33, 'Lawyer');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES
# ('John', 25, 'Engineer'),
# ('Jane', 35, 'Doctor'),
# ('Doe', 45, 'Teacher'),
# ('Smith', 18, 'Student'),
# ('Brown', 28, 'Artist'),
# ('Johnson', 38, 'Writer'),
# ('Williams', 48, 'Musician'),
# ('Jones', 22, 'Designer'),
# ('Garcia', 32, 'Chef'),
# ('Miller', 50, 'Nurse');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession) VALUES\n('John', 25, 'Engineer'),\n('Jane', 35, 'Doctor'),\n('Doe', 45, 'Teacher'),\n('Smith', 18, 'Student'),\n('Brown', 28, 'Artist'),\n('Johnson', 38, 'Writer'),\n('Williams', 48, 'Musician'),\n('Jones', 22, 'Designer'),\n('Garcia', 32, 'Chef'),\n('Miller', 50, 'Nurse');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# This is an example of a SELECT query in sqlite3:
# ```sql
# SELECT * FROM example_table;
# ```
#
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES
# ('John Doe', 25, 'Engineer'),
# ('Jane Doe', 30, 'Doctor'),
# ('Alice Smith', 40, 'Teacher'),
# ('Bob Johnson', 35, 'Artist'),
# ('Charlie Brown', 28, 'Writer'),
# ('David Wilson', 45, 'Lawyer'),
# ('Eva Davis', 32, 'Nurse'),
# ('Frank Miller', 29, 'Chef'),
# ('Grace Lee', 42, 'Architect'),
# ('Helen Clark', 38, 'Musician');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession) VALUES\n('John Doe', 25, 'Engineer'),\n('Jane Doe', 30, 'Doctor'),\n('Alice Smith', 40, 'Teacher'),\n('Bob Johnson', 35, 'Artist'),\n('Charlie Brown', 28, 'Writer'),\n('David Wilson', 45, 'Lawyer'),\n('Eva Davis', 32, 'Nurse'),\n('Frank Miller', 29, 'Chef'),\n('Grace Lee', 42, 'Architect'),\n('Helen Clark', 38, 'Musician');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters (Name, Age, Profession)
# VALUES ('Alice', 25, 'Doctor'),
#        ('Bob', 35, 'Engineer'),
#        ('Charlie', 40, 'Teacher'),
#        ('David', 28, 'Artist'),
#        ('Eve', 30, 'Writer'),
#        ('Frank', 45, 'Musician'),
#        ('Grace', 32, 'Nurse'),
#        ('Helen', 22, 'Lawyer'),
#        ('Ivy', 50, 'Chef'),
#        ('Jack', 38, 'Architect');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession)\nVALUES ('Alice', 25, 'Doctor'),\n       ('Bob', 35, 'Engineer'),\n       ('Charlie', 40, 'Teacher'),\n       ('David', 28, 'Artist'),\n       ('Eve', 30, 'Writer'),\n       ('Frank', 45, 'Musician'),\n       ('Grace', 32, 'Nurse'),\n       ('Helen', 22, 'Lawyer'),\n       ('Ivy', 50, 'Chef'),\n       ('Jack', 38, 'Architect');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('John Doe', 25, 'Engineer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Jane Doe', 30, 'Doctor');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Alice Smith', 28, 'Teacher');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Bob Johnson', 40, 'Artist');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie Brown', 35, 'Writer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Diana Prince', 45, 'Nurse');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Eddie Murphy', 50, 'Actor');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Frankie James', 32, 'Musician');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Gina Davis', 29, 'Chef');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Hank Adams', 42, 'Architect');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('John Doe', 25, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Jane Doe', 30, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Alice Smith', 28, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Bob Johnson', 40, 'Artist');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie Brown', 35, 'Writer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Diana Prince', 45, 'Nurse');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Eddie Murphy', 50, 'Actor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Frankie James', 32, 'Musician');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Gina Davis', 29, 'Chef');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Hank Adams', 42, 'Architect');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('Alice', 25, 'Engineer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Bob', 35, 'Doctor');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie', 45, 'Teacher');
# INSERT INTO characters (Name, Age, Profession) VALUES ('David', 18, 'Student');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Eve', 28, 'Artist');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Frank', 30, 'Writer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Grace', 40, 'Nurse');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Helen', 50, 'Lawyer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Ivy', 32, 'Musician');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Jack', 20, 'Chef');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('Alice', 25, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Bob', 35, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie', 45, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('David', 18, 'Student');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Eve', 28, 'Artist');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Frank', 30, 'Writer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Grace', 40, 'Nurse');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Helen', 50, 'Lawyer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Ivy', 32, 'Musician');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Jack', 20, 'Chef');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES
# ('Alice', 25, 'Doctor'),
# ('Bob', 30, 'Engineer'),
# ('Charlie', 35, 'Artist'),
# ('David', 40, 'Teacher'),
# ('Eve', 45, 'Nurse'),
# ('Frank', 50, 'Lawyer'),
# ('Grace', 20, 'Chef'),
# ('Helen', 28, 'Writer'),
# ('Ivan', 38, 'Architect'),
# ('Judy', 42, 'Musician');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession) VALUES\n('Alice', 25, 'Doctor'),\n('Bob', 30, 'Engineer'),\n('Charlie', 35, 'Artist'),\n('David', 40, 'Teacher'),\n('Eve', 45, 'Nurse'),\n('Frank', 50, 'Lawyer'),\n('Grace', 20, 'Chef'),\n('Helen', 28, 'Writer'),\n('Ivan', 38, 'Architect'),\n('Judy', 42, 'Musician');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES
# ('Alice', 25, 'Engineer'),
# ('Bob', 30, 'Doctor'),
# ('Charlie', 35, 'Artist'),
# ('David', 40, 'Teacher'),
# ('Eve', 45, 'Nurse'),
# ('Frank', 50, 'Lawyer'),
# ('Grace', 20, 'Chef'),
# ('Helen', 25, 'Writer'),
# ('Ivy', 30, 'Musician'),
# ('Jack', 35, 'Architect');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession) VALUES\n('Alice', 25, 'Engineer'),\n('Bob', 30, 'Doctor'),\n('Charlie', 35, 'Artist'),\n('David', 40, 'Teacher'),\n('Eve', 45, 'Nurse'),\n('Frank', 50, 'Lawyer'),\n('Grace', 20, 'Chef'),\n('Helen', 25, 'Writer'),\n('Ivy', 30, 'Musician'),\n('Jack', 35, 'Architect');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('John Doe', 25, 'Engineer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Jane Doe', 30, 'Doctor');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Alice Smith', 40, 'Teacher');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Bob Johnson', 35, 'Artist');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie Brown', 28, 'Writer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Diana Prince', 45, 'Nurse');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Eddie Murphy', 38, 'Actor');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Fiona Apple', 22, 'Singer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('George Clooney', 50, 'Actor');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Helen Keller', 32, 'Author');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('John Doe', 25, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Jane Doe', 30, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Alice Smith', 40, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Bob Johnson', 35, 'Artist');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie Brown', 28, 'Writer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Diana Prince', 45, 'Nurse');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Eddie Murphy', 38, 'Actor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Fiona Apple', 22, 'Singer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('George Clooney', 50, 'Actor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Helen Keller', 32, 'Author');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('John', 25, 'Engineer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Jane', 30, 'Doctor');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Bob', 35, 'Teacher');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Alice', 40, 'Nurse');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie', 45, 'Artist');
# INSERT INTO characters (Name, Age, Profession) VALUES ('David', 50, 'Lawyer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Eva', 22, 'Engineer');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Frank', 28, 'Doctor');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Grace', 32, 'Teacher');
# INSERT INTO characters (Name, Age, Profession) VALUES ('Heidi', 37, 'Nurse');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters (Name, Age, Profession) VALUES ('John', 25, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Jane', 30, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Bob', 35, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Alice', 40, 'Nurse');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Charlie', 45, 'Artist');", "INSERT INTO characters (Name, Age, Profession) VALUES ('David', 50, 'Lawyer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Eva', 22, 'Engineer');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Frank', 28, 'Doctor');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Grace', 32, 'Teacher');", "INSERT INTO characters (Name, Age, Profession) VALUES ('Heidi', 37, 'Nurse');"]
# --------------------------------------------------------------------------------

# %%
cursor.execute("DELETE FROM characters20")
apply_insert_prompt(characters20, n_iter=5, n_lines=20)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# FIRST GENERATION
# ```sql
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('John Doe', 25, 'Engineer'), ('Jane Doe', 30, 'Doctor'), ('Alice Smith', 40, 'Teacher'), ('Bob Johnson', 35, 'Artist'), ('Charlie Brown', 28, 'Writer'), ('Diana Prince', 45, 'Nurse'), ('Eli Johnson', 50, 'Teacher'), ('Frank Smith', 32, 'Engineer'), ('Grace Lee', 27, 'Doctor'), ('Helen Davis', 42, 'Artist'), ('Ian Brown', 38, 'Writer'), ('Judy Johnson', 29, 'Nurse'), ('Karen Smith', 48, 'Teacher'), ('Larry Brown', 33, 'Engineer'), ('Megan Davis', 26, 'Doctor'), ('Nancy Johnson', 43, 'Artist'), ('Oscar Lee', 31, 'Writer'), ('Peggy Davis', 49, 'Nurse'), ('Quincy Johnson', 24, 'Teacher');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters20 (Name, Age, Profession) VALUES ('John Doe', 25, 'Engineer'), ('Jane Doe', 30, 'Doctor'), ('Alice Smith', 40, 'Teacher'), ('Bob Johnson', 35, 'Artist'), ('Charlie Brown', 28, 'Writer'), ('Diana Prince', 45, 'Nurse'), ('Eli Johnson', 50, 'Teacher'), ('Frank Smith', 32, 'Engineer'), ('Grace Lee', 27, 'Doctor'), ('Helen Davis', 42, 'Artist'), ('Ian Brown', 38, 'Writer'), ('Judy Johnson', 29, 'Nurse'), ('Karen Smith', 48, 'Teacher'), ('Larry Brown', 33, 'Engineer'), ('Megan Davis', 26, 'Doctor'), ('Nancy Johnson', 43, 'Artist'), ('Oscar Lee', 31, 'Writer'), ('Peggy Davis', 49, 'Nurse'), ('Quincy Johnson', 24, 'Teacher');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Alice', 25, 'Engineer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Bob', 30, 'Doctor');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Charlie', 35, 'Teacher');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('David', 40, 'Artist');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Eve', 45, 'Nurse');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Frank', 50, 'Lawyer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Grace', 55, 'Artist');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Helen', 60, 'Teacher');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ivy', 65, 'Doctor');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Jack', 70, 'Engineer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Karen', 75, 'Nurse');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Linda', 80, 'Lawyer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Megan', 85, 'Artist');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Nancy', 90, 'Teacher');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Oscar', 95, 'Doctor');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Paul', 100, 'Engineer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Quinn', 105, 'Nurse');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Rachel', 110, 'Lawyer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Sam', 115, 'Artist');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Tina', 120, 'Teacher');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ursula', 125, 'Doctor');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Victor', 130, 'Engineer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Wanda', 135, 'Nurse');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Xavier', 140, 'Lawyer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Yvette', 145, 'Artist');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Zachary', 150, 'Teacher');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters20 (Name, Age, Profession) VALUES ('Alice', 25, 'Engineer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Bob', 30, 'Doctor');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Charlie', 35, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('David', 40, 'Artist');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Eve', 45, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Frank', 50, 'Lawyer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Grace', 55, 'Artist');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Helen', 60, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ivy', 65, 'Doctor');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Jack', 70, 'Engineer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Karen', 75, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Linda', 80, 'Lawyer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Megan', 85, 'Artist');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Nancy', 90, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Oscar', 95, 'Doctor');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Paul', 100, 'Engineer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Quinn', 105, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Rachel', 110, 'Lawyer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Sam', 115, 'Artist');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Tina', 120, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ursula', 125, 'Doctor');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Victor', 130, 'Engineer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Wanda', 135, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Xavier', 140, 'Lawyer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Yvette', 145, 'Artist');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Zachary', 150, 'Teacher');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('John', 25, 'Engineer'), ('Jane', 30, 'Doctor'), ('Alice', 40, 'Teacher'), ('Bob', 50, 'Artist'), ('Charlie', 35, 'Writer'), ('David', 45, 'Musician'), ('Eve', 28, 'Designer'), ('Frank', 32, 'Architect'), ('Grace', 48, 'Nurse'), ('Heidi', 38, 'Artist'), ('Ian', 22, 'Chef'), ('Judy', 37, 'Nurse'), ('Karen', 42, 'Teacher'), ('Linda', 29, 'Designer'), ('Martha', 50, 'Writer'), ('Nancy', 40, 'Musician'), ('Oscar', 33, 'Chef'), ('Paul', 26, 'Designer'), ('Quinn', 39, 'Nurse'), ('Rachel', 41, 'Teacher'), ('Sam', 27, 'Musician'), ('Tina', 31, 'Designer'), ('Ursula', 49, 'Writer'), ('Victor', 36, 'Chef'), ('Wendy', 23, 'Designer');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters20 (Name, Age, Profession) VALUES ('John', 25, 'Engineer'), ('Jane', 30, 'Doctor'), ('Alice', 40, 'Teacher'), ('Bob', 50, 'Artist'), ('Charlie', 35, 'Writer'), ('David', 45, 'Musician'), ('Eve', 28, 'Designer'), ('Frank', 32, 'Architect'), ('Grace', 48, 'Nurse'), ('Heidi', 38, 'Artist'), ('Ian', 22, 'Chef'), ('Judy', 37, 'Nurse'), ('Karen', 42, 'Teacher'), ('Linda', 29, 'Designer'), ('Martha', 50, 'Writer'), ('Nancy', 40, 'Musician'), ('Oscar', 33, 'Chef'), ('Paul', 26, 'Designer'), ('Quinn', 39, 'Nurse'), ('Rachel', 41, 'Teacher'), ('Sam', 27, 'Musician'), ('Tina', 31, 'Designer'), ('Ursula', 49, 'Writer'), ('Victor', 36, 'Chef'), ('Wendy', 23, 'Designer');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('John Doe', 25, 'Engineer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Jane Doe', 30, 'Doctor');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Alice Smith', 28, 'Teacher');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Bob Johnson', 35, 'Artist');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Charlie Brown', 40, 'Writer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('David Miller', 45, 'Architect');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Eva Wilson', 50, 'Nurse');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Frank Davis', 32, 'Chef');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Grace Lee', 22, 'Musician');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Helen Green', 38, 'Lawyer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ivan Clark', 42, 'Teacher');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Judy Brown', 27, 'Artist');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Karen White', 34, 'Writer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Linda Adams', 48, 'Nurse');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Michael Brown', 36, 'Chef');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Nancy Davis', 29, 'Musician');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Owen Green', 41, 'Lawyer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Patricia Clark', 31, 'Teacher');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Quentin Brown', 50, 'Architect');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Rachel Wilson', 26, 'Nurse');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Samuel Davis', 33, 'Chef');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Tina Green', 44, 'Writer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ursula Adams', 39, 'Musician');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Victor Clark', 37, 'Lawyer');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Wendy Brown', 46, 'Teacher');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Xavier Wilson', 30, 'Architect');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Yvonne Davis', 28, 'Nurse');
# INSERT INTO characters20 (Name, Age, Profession) VALUES ('Zachary Green', 40, 'Chef');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters20 (Name, Age, Profession) VALUES ('John Doe', 25, 'Engineer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Jane Doe', 30, 'Doctor');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Alice Smith', 28, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Bob Johnson', 35, 'Artist');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Charlie Brown', 40, 'Writer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('David Miller', 45, 'Architect');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Eva Wilson', 50, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Frank Davis', 32, 'Chef');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Grace Lee', 22, 'Musician');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Helen Green', 38, 'Lawyer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ivan Clark', 42, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Judy Brown', 27, 'Artist');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Karen White', 34, 'Writer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Linda Adams', 48, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Michael Brown', 36, 'Chef');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Nancy Davis', 29, 'Musician');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Owen Green', 41, 'Lawyer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Patricia Clark', 31, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Quentin Brown', 50, 'Architect');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Rachel Wilson', 26, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Samuel Davis', 33, 'Chef');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Tina Green', 44, 'Writer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Ursula Adams', 39, 'Musician');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Victor Clark', 37, 'Lawyer');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Wendy Brown', 46, 'Teacher');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Xavier Wilson', 30, 'Architect');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Yvonne Davis', 28, 'Nurse');", "INSERT INTO characters20 (Name, Age, Profession) VALUES ('Zachary Green', 40, 'Chef');"]
# --------------------------------------------------------------------------------
# FIRST GENERATION
# ```sql
# INSERT INTO characters20 (Name, Age, Profession) VALUES
# ('John Doe', 25, 'Actor'),
# ('Jane Doe', 30, 'Doctor'),
# ('Alice Smith', 40, 'Teacher'),
# ('Bob Johnson', 35, 'Engineer'),
# ('Charlie Brown', 28, 'Artist'),
# ('Diana Prince', 22, 'Nurse'),
# ('Eve Adams', 45, 'Lawyer'),
# ('Frank Davis', 32, 'Chef'),
# ('Grace Miller', 29, 'Writer'),
# ('Helen Wilson', 38, 'Artist'),
# ('Ivy Harris', 27, 'Teacher'),
# ('Jack Clark', 42, 'Engineer'),
# ('Karen Lee', 31, 'Doctor'),
# ('Linda Brown', 26, 'Nurse'),
# ('Martha Davis', 39, 'Writer'),
# ('Nancy Adams', 24, 'Chef'),
# ('Oscar Johnson', 37, 'Teacher'),
# ('Paul Miller', 41, 'Lawyer'),
# ('Quincy Wilson', 23, 'Engineer'),
# ('Rachel Clark', 34, 'Nurse'),
# ('Susan Davis', 21, 'Writer');
# ```</s>
# --------------------------------------------------------------------------------
# FIRST MATCH
# ["INSERT INTO characters20 (Name, Age, Profession) VALUES\n('John Doe', 25, 'Actor'),\n('Jane Doe', 30, 'Doctor'),\n('Alice Smith', 40, 'Teacher'),\n('Bob Johnson', 35, 'Engineer'),\n('Charlie Brown', 28, 'Artist'),\n('Diana Prince', 22, 'Nurse'),\n('Eve Adams', 45, 'Lawyer'),\n('Frank Davis', 32, 'Chef'),\n('Grace Miller', 29, 'Writer'),\n('Helen Wilson', 38, 'Artist'),\n('Ivy Harris', 27, 'Teacher'),\n('Jack Clark', 42, 'Engineer'),\n('Karen Lee', 31, 'Doctor'),\n('Linda Brown', 26, 'Nurse'),\n('Martha Davis', 39, 'Writer'),\n('Nancy Adams', 24, 'Chef'),\n('Oscar Johnson', 37, 'Teacher'),\n('Paul Miller', 41, 'Lawyer'),\n('Quincy Wilson', 23, 'Engineer'),\n('Rachel Clark', 34, 'Nurse'),\n('Susan Davis', 21, 'Writer');"]
# --------------------------------------------------------------------------------

# %%
print(
    f"Number of rows in characters: {cursor.execute('SELECT COUNT(*) FROM characters;').fetchone()[0]}"
)
print(
    f"Number of rows in characters20: {cursor.execute('SELECT COUNT(*) FROM characters20;').fetchone()[0]}"
)
# Out:
# Number of rows in characters: 70
# Number of rows in characters20: 107

# %% [markdown]
# ## 3. Explore our tables using llm.
#
# First, you need to generate and execute SQL queries that indicate the number of duplicate rows (without ids) in each character table. To make things easier, we only ask for the number of each duplicated rows.
#
# Here is an examples of expected results:
#
# ```
# [(2,), (7,), (5,), (2,), (2,), (3,), (2,), (2,), (2,), (2,), (2,), (2,), (2,)]
# ```
#
# <font color='green'> BONUS: Generate a query that returns the total count of duplicated rows. You may need to do this in several steps.</font>
#
# Secondly, you need to generate and execute SQL queries that remove duplicate rows. To make things easier, it's not necessary to keep original duplicated lines. For example, if you have a list like this : [a, b, a, c]. We ask you to remove all the a: [b, c].
#
# <font color='green'> BONUS: Generate a query that delete duplicated but keep the original row. [a, b, a, c] -> [a, b, c] </font>
#
# Finaly, you need to generate and execute SQL queries that check if the age constraint is respected.
#
# <font color='red'> BE CAREFUL: Do each step for every characters tables you have.</font>

# %%
template_query = """
You have this SQLite table:
{table}

Write the SQLite3 query to do satisfy this request: {action}

The query should be written in sqlite3 syntax, you are not allowed to use any other language syntax.
The query should be written between ```sql <QUERY>```.
"""

actions = [
    "Compute ONLY the total number of duplicate rows (ALL columns without ids), separately for each row. The result should be like this: [(2,), (7,), (5,), ...]",
    # "First compute the count of duplicate rows (ALL columns without ids), separately for each row. Then sum these values. The final result should be like this: [(14,)]",
    "First compute the count of duplicate rows (ALL columns without ids), separately for each row. Then delete these rows.",
    # "Show the rows where the age is lower than 18 or greater than 50.",
]


def apply_query_prompt(t_name, table, action):
    prompt_text = template_query.format(table=table, action=action)
    input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

    generation_output = llm.generate(
        input_ids=input_ids,
        generation_config=generation_config,
    )
    generation_text = tokenizer.decode(generation_output[0][len(input_ids[0]) :])
    print("GENERATION")
    print(generation_text)
    print("-" * 80)

    matches = re.search(r"```sql(.*?)```", generation_text, re.DOTALL)
    if matches is None:
        raise Exception("No matches found")
    match = matches.group(0).split("\n")[1:-1]
    match = "\n".join(match)
    print("MATCHES")
    print(match)
    print("-" * 80)

    try:
        print(
            f"Table: {t_name}, Action: {action}\n{cursor.execute(match).fetchall()}\n"
        )
    except Exception as e:
        print(e)


for action in actions:
    for t_name, table in {
        "characters": characters,
        "characters20": characters20,
    }.items():
        apply_query_prompt(t_name, table, action)
# Out:
# GENERATION
# ```sql
# SELECT COUNT(*)
# FROM characters
# GROUP BY Name, Age, Profession
# HAVING COUNT(*) > 1
# ```
#
# This query will give you the total number of duplicate rows for each row, separately for each row. The result will be like this: [(2,), (7,), (5,), ...]</s>
# --------------------------------------------------------------------------------
# MATCHES
# SELECT COUNT(*)
# FROM characters
# GROUP BY Name, Age, Profession
# HAVING COUNT(*) > 1
# --------------------------------------------------------------------------------
# Table: characters, Action: Compute ONLY the total number of duplicate rows (ALL columns without ids), separately for each row. The result should be like this: [(2,), (7,), (5,), ...]
# []
# GENERATION
# ```sql
# SELECT COUNT(*)
# FROM characters20
# GROUP BY Name, Age, Profession
# HAVING COUNT(*) > 1
# ```
#
# This query groups the rows by the columns `Name`, `Age`, and `Profession`, and then counts the number of duplicates for each group. The `HAVING` clause filters out the groups that have only one row, leaving only the groups with duplicates. The `COUNT(*)` function counts the number of rows in each group, and the result is a list of tuples, where each tuple contains the count of duplicates for a specific group.</s>
# --------------------------------------------------------------------------------
# MATCHES
# SELECT COUNT(*)
# FROM characters20
# GROUP BY Name, Age, Profession
# HAVING COUNT(*) > 1
# --------------------------------------------------------------------------------
# Table: characters20, Action: Compute ONLY the total number of duplicate rows (ALL columns without ids), separately for each row. The result should be like this: [(2,), (7,), (5,), ...]
# []
# GENERATION
# ```sql
# -- Step 1: Compute the count of duplicate rows (ALL columns without ids)
# WITH duplicate_counts AS (
#     SELECT
#         Name,
#         Age,
#         Profession,
#         COUNT(*) AS count
#     FROM
#         characters
#     GROUP BY
#         Name,
#         Age,
#         Profession
#     HAVING
#         COUNT(*) > 1
# )
# -- Step 2: Delete these rows
# DELETE FROM characters
# WHERE
#     (Name, Age, Profession) IN (
#         SELECT
#             Name,
#             Age,
#             Profession
#         FROM
#             duplicate_counts
#     );
# ```</s>
# --------------------------------------------------------------------------------
# MATCHES
# -- Step 1: Compute the count of duplicate rows (ALL columns without ids)
# WITH duplicate_counts AS (
#     SELECT
#         Name,
#         Age,
#         Profession,
#         COUNT(*) AS count
#     FROM
#         characters
#     GROUP BY
#         Name,
#         Age,
#         Profession
#     HAVING
#         COUNT(*) > 1
# )
# -- Step 2: Delete these rows
# DELETE FROM characters
# WHERE
#     (Name, Age, Profession) IN (
#         SELECT
#             Name,
#             Age,
#             Profession
#         FROM
#             duplicate_counts
#     );
# --------------------------------------------------------------------------------
# Table: characters, Action: First compute the count of duplicate rows (ALL columns without ids), separately for each row. Then delete these rows.
# []
# GENERATION
# ```sql
# -- Step 1: Compute the count of duplicate rows (ALL columns without ids)
# WITH DuplicateCounts AS (
#     SELECT
#         Name,
#         Age,
#         Profession,
#         COUNT(*) AS DuplicateCount
#     FROM
#         characters20
#     GROUP BY
#         Name,
#         Age,
#         Profession
#     HAVING
#         COUNT(*) > 1
# )
# -- Step 2: Delete these rows
# DELETE FROM characters20
# WHERE
#     (Name, Age, Profession) IN (
#         SELECT
#             Name,
#             Age,
#             Profession
#         FROM
#             DuplicateCounts
#     );
# ```
#
# This query first computes the count of duplicate rows (ALL columns without ids) and then deletes these rows.</s>
# --------------------------------------------------------------------------------
# MATCHES
# -- Step 1: Compute the count of duplicate rows (ALL columns without ids)
# WITH DuplicateCounts AS (
#     SELECT
#         Name,
#         Age,
#         Profession,
#         COUNT(*) AS DuplicateCount
#     FROM
#         characters20
#     GROUP BY
#         Name,
#         Age,
#         Profession
#     HAVING
#         COUNT(*) > 1
# )
# -- Step 2: Delete these rows
# DELETE FROM characters20
# WHERE
#     (Name, Age, Profession) IN (
#         SELECT
#             Name,
#             Age,
#             Profession
#         FROM
#             DuplicateCounts
#     );
# --------------------------------------------------------------------------------
# Table: characters20, Action: First compute the count of duplicate rows (ALL columns without ids), separately for each row. Then delete these rows.
# []

# %% [markdown]
# ## 4. More than one table with llm.
#
# First, choose your best characters table (with the largest number of rows).
#
# Second, generate and execute an SQL query that returns the set of unique professions in the table.
#
# Third, generate and execute an SQL query that populates the skill tables from this set of unique professions.
#
# Fourth, generate and execute an SQL query that verifies that the professions in the skill table exist in your characters table.
#
# Finally, generate and execute an SQL query that returns the name of the skills associated with a character name (by profession).

# %%
# select the table with the largest number of rows
table = (
    "characters"
    if cursor.execute("SELECT COUNT(*) FROM characters;").fetchone()[0]
    > cursor.execute("SELECT COUNT(*) FROM characters20;").fetchone()[0]
    else "characters20"
)

# %%
actions = [
    "Select the set of unique professions in the table.",
    "Populate the skills tables from this set of unique professions.",
    "Verify that the professions in the skills table exist in characters table.",
    "Return the name of the skills associated with a character name (by profession).",
]
