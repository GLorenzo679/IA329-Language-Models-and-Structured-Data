# %% [markdown]
# # Lab 4: Text to SQL
#
# In this lab, we'll apply what we've already learned in the previous labs to build a sqlite database using Ministral 8b. This lab is less guided than the previous ones and you'll need to refer to what you've done previously to complete each part. Moreover, this lab is more focused on prompt engineering and you have to find the best prompt and prompt strategy (system prompt? temperature value? dialog prompt style?).
#
# For this lab, we need to use sqlite3 to execute the generated queries.
# Check the doc: https://docs.python.org/3/library/sqlite3.html
#
# <font color='red'>BE CAREFUL: you need to generate sql queries then automaticly exectute them with sqlite3 connector. DO NOT generate python code. DO NOT copy paste genereted query to the connector.</font>
#
# <font color='green'>TIPS: sqlite3 create a file containing your db. Delete it if you need to reset the db.</font>
#
# Lab overview:
#
# 0. Modules installation and model loading.
# 1. Create tables using llm.
# 2. Populate tables using llm.
# 3. Explore our tables using llm.
# 4. More than one table with llm.
#
# IMPORTANT:
#
# - You must work in pairs. You must submit **ONLY ONE NOTEBOOK** for each pair.
# - Do not share your work with other pairs.
# - You should not use Copilot, ChatGPT or similar tools. At the very least, remove the prompt ...

# %% [markdown]
# ## 0. Setup

# %%
# !pip install -U transformers datasets bitsandbytes accelerate
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Collecting transformers
#   Downloading transformers-4.48.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.45.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.2.1)
# Collecting accelerate
#   Downloading accelerate-1.3.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.11)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.5.1+cu121)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->bitsandbytes) (3.0.2)
# Downloading transformers-4.48.1-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 44.5 MB/s eta 0:00:00
# Downloading accelerate-1.3.0-py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 27.7 MB/s eta 0:00:00
# Installing collected packages: transformers, accelerate
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.47.1
#     Uninstalling transformers-4.47.1:
#       Successfully uninstalled transformers-4.47.1
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.2.1
#     Uninstalling accelerate-1.2.1:
#       Successfully uninstalled accelerate-1.2.1
# Successfully installed accelerate-1.3.0 transformers-4.48.1

# %%
from transformers import (
    BitsAndBytesConfig,
    AutoTokenizer,
    AutoModelForCausalLM,
    GenerationConfig
)

from tqdm import tqdm
import pandas as pd
import sqlite3
import torch
import re

# %%
# Put your hugging face token here: https://huggingface.co/docs/hub/en/security-tokens
# You need to fill the access form with your huggingface account on this link: https://huggingface.co/mistralai/Ministral-8B-Instruct-2410
hf_token = ""
llm_name = "mistralai/Ministral-8B-Instruct-2410"

# We want to use 4bit quantization to save memory
quantization_config = BitsAndBytesConfig(
    load_in_8bit=False, load_in_4bit=True
)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(llm_name, padding_side="left", token=hf_token)
# Prevent some transformers specific issues.
tokenizer.use_default_system_prompt = False
tokenizer.pad_token_id = tokenizer.eos_token_id

# Load LLM.
llm = AutoModelForCausalLM.from_pretrained(
    llm_name,
    quantization_config=quantization_config,
    device_map={"": 0}, # load all the model layers on GPU 0
    torch_dtype=torch.bfloat16, # float precision
    token=hf_token
)
# Set LLM on eval mode.
llm.eval()
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message.
# model.safetensors.index.json:   0%|          | 0.00/26.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.07G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(131072, 4096)
#     (layers): ModuleList(
#       (0-35): 36 x MistralDecoderLayer(
#         (self_attn): MistralAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): MistralMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=12288, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=12288, bias=False)
#           (down_proj): Linear4bit(in_features=12288, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): MistralRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): MistralRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): MistralRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=131072, bias=False)
# )

# %% [markdown]
# ## 1. Create tables using llms
#
# You need to generate and execute SQL queries to create 3 tables:
#
# - "characters": Id (primary key), Name (str), Age (int), Profession (int).
# - "characters20": same than characters.
# - "skills": Id (primary key), Name (str), Profession (str).
#
# For example, by running this code `cursor.execute("""PRAGMA table_info(characters);""").fetchall()`.
#
# You should have this results:
#
# ```
# `[(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'name', 'TEXT', 1, None, 0),
#  (2, 'age', 'INTEGER', 1, None, 0),
#  (3, 'profession', 'TEXT', 1, None, 0)]
# ```
#
# <font color='red'>BE CAREFUL: sqlite3 doesn't have the same possibility than SQL. You may need to specify it.</font>

# %%
generation_config = GenerationConfig(
 max_new_tokens=512,
    #do_sample=False,
    do_sample=True,
    # temperature=.7,
    # top_p=.8,
    # top_k=20,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.pad_token_id,
)

# %%
characters = """characters(Id (primary key autoincrement), Name (str not null), Age (int not null), Profession (str not null))"""
characters20 = """characters20(Id (primary key autoincrement), Name (str not null), Age (int not null), Profession (str not null))"""
skills = """skills(Id (primary key autoincrement), Name (str not null), Profession (str not null))"""

template_create = """
This is the table:
{table}
This is the text:
Write the query to create the table in sqlite3.
```
""";
template_refine = """
This is the table:
{table}
This is the text:
Write the query to create the table in sqlite3.
This is the reference:
```sql
{reference}
```
The reference SQL may be correct or incorrect.
If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
"""

tables = [characters, characters20, skills]
#create sqlite cursor
conn = sqlite3.connect('lab4.db')
cursor = conn.cursor()

# %%
def generate_execute_sql(table):
  prompt_text = template_create.format(table=table)
  input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

  generation_output = llm.generate(
      input_ids=input_ids,
      generation_config=generation_config,
  )
  generation_text = tokenizer.decode(generation_output[0])

  matches = re.findall(r"CREATE TABLE .*?\)", generation_text, re.DOTALL | re.IGNORECASE)
  if len(matches) == 0:
    print(generation_text)
    print("No matches found")
    return
  #last match
  prompt_text = template_refine.format(table=table, reference=matches[-1])
  input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

  generation_output = llm.generate(
      input_ids=input_ids,
      generation_config=generation_config,
  )
  generation_text = tokenizer.decode(generation_output[0])

  #extract from the CREATE TABLE to ;

  matches = re.findall(r"CREATE TABLE .*?\)", generation_text, re.DOTALL | re.IGNORECASE)
  #last match
  print(matches[-1])
  #add try and catch
  try:
    cursor.execute(matches[-1])
    conn.commit()
  except:
    print("Error")


#clear all tables
cursor.execute("DROP TABLE IF EXISTS characters")
cursor.execute("DROP TABLE IF EXISTS characters20")
cursor.execute("DROP TABLE IF EXISTS skills")
conn.commit()
for table in tables:
  generate_execute_sql(table)
# Out:
# CREATE TABLE characters (
#     Id INTEGER PRIMARY KEY AUTOINCREMENT,
#     Name TEXT NOT NULL,
#     Age INTEGER NOT NULL CHECK (Age BETWEEN 18 AND 49)
# Error
# CREATE TABLE characters (
# Id INTEGER AUTO_INCREMENT,
# Name TEXT NOT NULL,
# Age INTEGER NOT NULL,
# Profession TEXT NOT NULL,
# PRIMARY KEY (Id)
# Error
# CREATE TABLE skills (
#     Id INTEGER PRIMARY KEY AUTOINCREMENT,
#     Name TEXT NOT NULL,
#     Profession TEXT NOT NULL
# )

# %%
print(cursor.execute(f"PRAGMA table_info(characters);").fetchall())
print(cursor.execute(f"PRAGMA table_info(characters20);").fetchall())
print(cursor.execute(f"PRAGMA table_info(skills);").fetchall())
# Out:
# [(0, 'Id', 'INTEGER', 0, None, 1), (1, 'Name', 'TEXT', 1, None, 0), (2, 'Age', 'INTEGER', 1, None, 0), (3, 'Profession', 'TEXT', 1, None, 0)]
# []
# [(0, 'Id', 'INTEGER', 0, None, 1), (1, 'Name', 'TEXT', 1, None, 0), (2, 'Profession', 'TEXT', 1, None, 0)]

# %% [markdown]
# ## 2. Populate tables using llm
#
# You need to generate and execute SQL queries to fill in “characters” and “characters20” :
#
# - For both, the age must be constrained between 18 and 50 (we'll assess whether the constraint is met later).
# - For “characters”, generate 10 rows using the prompt. Apply the prompt 10 times (you should end up with 100 lines).
# - For “characters20”, generate 20 rows using the prompt. Apply the prompt 5 times (you should also get 100 lines at the end).
#
# For example, executing this code `cursor.execute("SELECT * FROM characters")`.
#
# You should get this result (with 100 rows and perhaps different values ...) :
#
# ```
# [(1, 'Alice', 25, 'Artist'),
#  (2, 'Bob', 35, 'Engineer'),
#   ...
#  (99, 'Ian', 32, 'Architect'),
#  (100, 'Jane', 18, 'Dancer')]
# ```
#
# <font color='red'> BE CAREFUL: If your generation configuration doesn't include sampling, you'll always have the same rows.</font>
#
# <font color='green'> BONUS: In section 3, we'll compare the number of duplicated rows between the two methods. Do you have a better strategy for minimizing the number of duplicated rows? Give it a try! (create another table for this purpose) </font>

# %%
template_insert = """
This is the table:
{table}
This is the text:
Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
This is an example of insertion in sqlite3:
```sql
INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
```
""";
template_insert_refine = """
This is the table:
{table}
This is the text:
Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
This is the reference:
```sql
{reference}
```
The reference SQL may be correct or incorrect.
If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
"""

def populate_table(table, reference, n):
  prompt_text = template_insert_refine.format(table=table, reference=reference)
  input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")
  print(reference)
  for i in range(n):
    generation_output = llm.generate(
        input_ids=input_ids,
        generation_config=generation_config,
    )
    answer = tokenizer.decode(generation_output[0])
    print(answer)
    matches = re.findall(r"INSERT INTO .*?;", answer, re.DOTALL | re.IGNORECASE)[-1]
    print(matches[-1])

    try:
      cursor.execute(matches[-1])
      conn.commit()
    except:
      print("Error")

def apply_prompt(table, n, n_rows):
  for i in tqdm(range(n)):
    prompt_text = template_insert.format(table=table)
    input_ids = tokenizer.encode(prompt_text, return_tensors="pt").to("cuda")

    generation_output = llm.generate(
        input_ids=input_ids,
        generation_config=generation_config,
    )
    generation_text = tokenizer.decode(generation_output[0])


    populate_table(table, re.findall(r"INSERT INTO .*?;", generation_text, re.DOTALL | re.IGNORECASE)[-1], n_rows)


apply_prompt(characters, 10, 10)
apply_prompt(characters20, 5, 20)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('Name', 26, 'Profession');
# ```
# The correct SQLite query is:
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('Name', 26, 'Profession');
# ```
# ```</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# If the reference SQL seems to be missing required or sufficient information but the query seems in sqlite3 format, output:
# `It seems to be missing required or sufficient information. '
#
# If the reference SQL is SQLite, please write the correct SQLite.
#
# 1. The reference SQL seems to be correct and complete:
# INSERT INTO characters (`Name`, `Age`, `Profession`) VALUES ('John', 25, 'Teacher');
# It is correct.
#
# 2. The reference SQL seems to be incorrect. The 'Name' needs to be quoted as 'str' type, and the 'age' needs to be between 18 and 50. Modify the reference SQL:
#
# `INSERT INTO characters (Name, Age, Profession) VALUES ('John', '25', 'Teacher')`</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# If the reference SQL is about something else like a different database language, it is incorrect.
# If the reference SQL is for creating a table like the one you are answering, it is incorrect.
#
# Let's work through the task step-by-step:
#
# 1. **Understanding the task requirements:**
#    - We have a table definition.
#    - We need to insert a row into this table.
#    - We need to ensure that the inserted Age is greater than or equal to 18 and less than 50.
#
# 2. **Understanding SQLite syntax:**
#    - The `INSERT INTO` statement is used to add a new row into a table.
#    - The `VALUES` clause specifies the data for the new row.
#
# 3. **Formulating the query:**
#    - We need to insert into the `characters` table.
#    - For the example, let's assume we are adding the characters:
#      - `Name = 'Alice'`
#      - `Age = 25`
#      - `Profession = 'Engineer'`
#    - This must be checked against the constraints provided (Age between 18 and 50).
#
# Let's form the query:
#
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('Alice', 25, 'Engineer');
# ```
#
# Since the `Age` here is `25` which falls within the range `>=18 <50`, the query is valid.
#
# Conclusion:
# The original reference SQL provided is correct and meets the requirements for inserting a row into the given `characters` table.
#
# **Final Answer:**
# It is correct.</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# Please add the values for Name, Age, and Profession. Set Age to 25, Name to 'John', and Profession to 'Truck Driver'</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('John', 25, 'Engineer');
# ```
# It is correct.</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```sql
# INSERT INTO characters (column1, column2, column3, column4) VALUES (column5, column6, column7, column8);
# ```
#
# It is correct.</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# Here is the answer (The values should be replaced with the actual values, with Name = "John", Age = 30, and Profession = "Engineer"):
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('John', 30, 'Engineer');
# ```</s>
# ;
#  10%|█         | 1/10 [01:28<13:16, 88.48s/it]
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# Here's the correct sqlite3 format SQLite query:
# ```sql
# INSERT INTO example_table (column1,column2) VALUES ('value1','value2');
# ```
# So, based on the requirements given and on the correct reference SQLite format, what would the sqlite3 format query be:
# ```
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# ```
# So, the correct SQLite3 format query would be:
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('John Doe', 30, 'Software Engineer');
# ```
# This correctly follows the provided table definition and uses the required values and format.
#
# If not all provided SQL formats are exactly right but almost correct, the modified format is also acceptable.
#
# If not all provided SQL formats are wrong then the incorrect format should be rejected. Only correct formats are considered for evaluation of the solution.</s>
# ;
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# If any statement in the question has a typo, list it if possible and suggest a possible correction.
# ****
#
# Yes, the reference SQL is correct.
#
# Correct format
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The correct statement with modifications would be:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example professional');
# ```
#
# However, as per the given text, there were no syntax errors.</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# Let's modify the reference.
# Correct SQLite:
# ```sql
# INSERT INTO characters (Name, Age, Profession) VALUES ('newname_here', 25, 'new_profession_here');
# ```
# So, the correct SQLite is as follows:
# It is correct.</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# The reference SQL may have been intended for a different type of database.
# If the reference SQL is incorrect, you may need to verify the details for the field sizes and types in the table definition.  (This is the table: The table may not be an actual table but may be described in the text.)</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```sqlite
# INSERT INTO characters(Id, Name, Age, Profession) VALUES (null, 'Name', 20, 'example_profession');
# ```
# ```</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# If it is the reference SQL is irrelevant for the query or does not support the table definition, please use the following query to insert a line of values:
# ```sql
# INSERT INTO Characters (Name, Age, Profession) VALUES (?, ?, ?)
# ```
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# It is correct.</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# Please answer the following:
#
# It is correct.</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# For instance, replace "example_profession" with the correct character for 'example_profession' (e.g., 'example_profession')
# Also, include the answer in the sqlite3 format as well.
#
# The task description includes the query to insert one line of values into the table in sqlite3.
# The correct SQL to insert one line of values into the table in sqlite3 is:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'Profession');
# ```</s>
# ;
#  20%|██        | 2/10 [02:59<11:59, 89.88s/it]
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('Name', 20, 'example_profession');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```sql
# INSERT INTO characters(Name, Age, Profession) VALUES ('example_name', 20, 'example_profession');
# ```</s>
# ;
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# This code will need to do all of it automatically.
#
# This is the Python script:
# def get_insert_sql_for_table(example_table, values):
#     id_name = 'id'
#     columns = ', '.join(f'`{col}`' for col in example_table)
#     values_str = ', '.join([f"'{val}'" if isinstance(val, str) else str(val) for val in values])
#     values_str = ', '.join([f"`{val}`" if isinstance(val, str) else str(val) for val in values]) # corrected for sqlite3
#     return f'INSERT INTO {example_table} ({columns}) VALUES ({values_str});'
# def get_values_expressions(example_table, values):
#     return ', '.join(['%s' for _ in values])
#
# def get_insert_sql(example_table, values):
#     columns = ', '.join(get_values_expressions(example_table, values))
#     values_str = ', '.join([f"'{val}'" if isinstance(val, str) else str(val) for val in values])
#     values_str = ', '.join([f"`{val}`" if isinstance(val, str) else str(val) for val in values]) # corrected for sqlite3
#     return f'INSERT INTO {example_table} ({columns}) VALUES ({values_str});'
# def get_default_insert_sql(example_table, values):
#     columns = ', '.join(['%s' for _ in values])
#     return f'INSERT INTO {example_table} ({columns}) VALUES ({columns});'
#
# # Function to execute INSERT query
# def execute_insert_query(data, database):
#     # Extract table name from data
#     table_name = data["table"][0]
#
#     # Extract column names
#     column_names = list(data["columns"].keys())
#
#     # Extract values for each row
#     row_values = list(data["values"][0])
#
#     # Get Insert SQL template
#     insert_sql = get_insert_sql(example_table=table_name, values=row_values)
#     # Return the generated SQL
#     return {'error': 'Not Available'}
#
# # Example usage:
# # Define the table schema with ID, Name, Age, and Profession
# table_schema = {
#     'table': [ 'characters' ],
#     'columns': {
#         'name': 'Name',
#         'age': 'Age',
#         'profession': 'Profession'
#     },
#     'values': [[ 'James' , 30 , 'Engineer' ]]
# }
#
# insert_query
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# Inserted 'Id', 'Name', 'profession', 'Age' to the table `characters`.
#
# ```sql
# INSERT INTO characters (Name, profession, Age, Profession) VALUES ('John Doe', 'Software Engineer', 30);
# ```</s>
# ;
# <s>
# This is the table:
# characters(Id (primary key autoincrement), Name (str not null), Age (int not null >=18 <50), Profession (str not null))
# This is the text:
# Write the query to insert one line of values (no ID) into the table in sqlite3. (age >=18 <50)
# This is the reference:
# ```sql
# INSERT INTO example_table (column1, column2) VALUES ('value1', 'value2');
# ```
# The reference SQL may be correct or incorrect.
# If the reference SQL is correct and written in sqlite3 format, just say 'It is correct. '.
# If the reference SQL is incorrect, modify the reference SQL and output the correct SQLite.
# ```</s>
# ;

# %%
print(cursor.execute("SELECT * FROM characters").fetchall())
# Out:
# []

# %% [markdown]
# ## 3. Explore our tables using llm.
#
# First, you need to generate and execute SQL queries that indicate the number of duplicate rows (without ids) in each character table. To make things easier, we only ask for the number of each duplicated rows.
#
# Here is an examples of expected results:
#
# ```
# [(2,), (7,), (5,), (2,), (2,), (3,), (2,), (2,), (2,), (2,), (2,), (2,), (2,)]
# ```
#
# <font color='green'> BONUS: Generate a query that returns the total count of duplicated rows. You may need to do this in several steps.</font>
#
# Secondly, you need to generate and execute SQL queries that remove duplicate rows. To make things easier, it's not necessary to keep original duplicated lines. For example, if you have a list like this : [a, b, a, c]. We ask you to remove all the a: [b, c].
#
# <font color='green'> BONUS: Generate a query that delete duplicated but keep the original row. [a, b, a, c] -> [a, b, c] </font>
#
# Finaly, you need to generate and execute SQL queries that check if the age constraint is respected.
#
# <font color='red'> BE CAREFUL: Do each step for every characters tables you have.</font>

# %% [markdown]
# ## 4. More than one table with llm.
#
# First, choose your best characters table (with the largest number of rows).
#
# Second, generate and execute an SQL query that returns the set of unique professions in the table.
#
# Third, generate and execute an SQL query that populates the skill tables from this set of unique professions.
#
# Fourth, generate and execute an SQL query that verifies that the professions in the skill table exist in your characters table.
#
# Finally, generate and execute an SQL query that returns the name of the skills associated with a character name (by profession).
